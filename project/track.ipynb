# %%
import cv2

rtsp_url = "rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101"

cap = cv2.VideoCapture(rtsp_url)

while True:
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imshow("RTSP Stream", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()

# %%
import sys
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID")
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID/mylibrary")

import cv2
import numpy as np
from mylibrary.utils.loader import LoadStreams  # Import the LoadStreams class from the specified module

# List of multiple RTSP sources
rtsp_sources = [
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/201',
]

# Initialize the LoadStreams class
streams = LoadStreams(sources=rtsp_sources, buffer=True)  # Specify whether to use a buffer

# for s, im, _, _ in streams.threads[0]:
#     cv2.imshow(f"RTSP Stream", np.hstack(im))
#     if streams.count>100:
#         streams.close()

# print(len(streams))
# cv2.destroyAllWindows()

# print(im)

# %%
import sys
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID")
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID/mylibrary")

import cv2
import numpy as np
from mylibrary.utils.loader import LoadStreams  # Import the LoadStreams class from the specified module

# List of multiple RTSP sources
rtsp_sources = [
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/201',
]

# Initialize the LoadStreams class
streams = LoadStreams(sources=rtsp_sources, buffer=True)  # Specify whether to use a buffer

iter(streams)
next(streams)
while True:
    next(streams)
    sources, images, _, _ = next(streams)
    cv2.imshow(sources[0], images[-1])
    if cv2.waitKey(1) == ord('q'):
        streams.close()
        raise StopIteration

# %%
import sys
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID")
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID/mylibrary")

import cv2
import numpy as np
from mylibrary.utils.loader import LoadStreams  # Import the LoadStreams class from the specified module

# List of multiple RTSP sources
rtsp_sources = [
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/201',
]

# Initialize the LoadStreams class
streams = LoadStreams(sources=rtsp_sources, buffer=True)  # Specify whether to use a buffer

while True:
    ret, frame = streams.caps[0].read()
    if not ret:
        break

    cv2.imshow("RTSP Stream", frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

streams.close()

# %%
import sys
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID")
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID/mylibrary")

import cv2
import numpy as np

from threading import Thread
import queue 

from mylibrary.utils.loader import LoadStreams  # Import the LoadStreams class from the specified module
from mylibrary.utils import LOGGER

# Define a generator function to create VideoCapture objects
def video_capture_generator(caps):
    yield from caps  # Iterate over VideoCapture objects in streams.caps

def show_video(idx, cap, frames_queue):
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        # Send the frame to the main thread for displaying
        frames_queue[idx].put(frame)

# List of multiple RTSP sources
rtsp_sources = [
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/201',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/301',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/401',
]

# Initialize the LoadStreams class
streams = LoadStreams(sources=rtsp_sources, imgsz=640, buffer=True)

# Create a queue for frames to be displayed in the main thread
frames_queue = [queue.Queue() for _ in rtsp_sources]

# Create a generator for VideoCapture objects
capture_gen = video_capture_generator(streams.caps)

# Create and start threads for each video source
threads = []
for i, cap in enumerate(capture_gen):
    thread = Thread(target=show_video, args=(i, cap, frames_queue))
    LOGGER.info(f'Video Thread ~~~~~~~~~~~~~~~~~~~~~ #{i}')
    threads.append(thread)
    thread.start()

# Create a main thread for displaying frames
while True:
    frames = [q.get() for q in frames_queue]

    for i, frame in enumerate(frames):
        window_name = f"RTSP Stream {i}"
        cv2.imshow(window_name, frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        streams.close()
        break

# Wait for all threads to complete
for thread in threads:
    thread.join()
# Out:
# 1/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
# 2/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/201... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
# 3/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/301... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
# 4/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/401... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
#
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #0
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #1
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #2
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #3
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
import sys
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID")
sys.path.append("/home/sunhokim/Documents/mygit/TrackAndRe-ID/mylibrary")

import cv2
import numpy as np

from threading import Thread
import queue 

from mylibrary.utils.loader import LoadStreamss  # Import the LoadStreams class from the specified module
from mylibrary.utils import LOGGER

# %%
def show_video(idx, cap, frames_queue):
    while True:
        ret, frame = cap.read()
        if not ret:
            break
        # Send the frame to the main thread for displaying
        frames_queue[idx].put(frame)

# List of multiple RTSP sources
rtsp_sources = [
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/201',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/301',
    'rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/401',
]

# Initialize the LoadStreams class
streams = LoadStreamss(sources=rtsp_sources, imgsz=640, buffer=True)

# Create a queue for frames to be displayed in the main thread
frames_queue = [queue.Queue() for _ in rtsp_sources]

# Create a generator for VideoCapture objects
capture_gen = streams.cap_gen()

# Create and start threads for each video source
threads = []
for i, cap in enumerate(capture_gen):
    thread = Thread(target=show_video, args=(i, cap, frames_queue))
    LOGGER.info(f'Video Thread ~~~~~~~~~~~~~~~~~~~~~ #{i}')
    threads.append(thread)
    thread.start()

# Create a main thread for displaying frames
while True:
    frames = [q.get() for q in frames_queue]

    for i, frame in enumerate(frames):
        window_name = f"RTSP Stream {i}"
        print(frame.shape) if i==1 else None
        cv2.imshow(window_name, frame)

    if cv2.waitKey(1) & 0xFF == ord('q'):
        streams.close()
        break

# Wait for all threads to complete
for thread in threads:
    thread.join()
# Out:
# 1/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/101... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
# 2/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/201... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
# 3/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/301... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
# 4/4: rtsp://admin:1234567s@10.160.30.13:554/Streaming/Channels/401... Success ✅ (inf frames of shape 1920x1080 at 15.00 FPS)
#
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #0
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #1
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #2
# Video Thread ~~~~~~~~~~~~~~~~~~~~~ #3
# The Kernel crashed while executing code in the the current cell or a previous cell. Please review the code in the cell(s) to identify a possible cause of the failure. Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info. View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
